# %%
import pandas as pd
import numpy as np
import re
import random

# %%
import nltk
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/fatma/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
unlabeled_tweets1 = pd.read_csv("Data/unlabeled_pos_twts.csv")
unlabeled_tweets2 = pd.read_csv("Data/unlabeled_neg_twts.csv")

# %%
unlabeled_tweets = pd.concat([unlabeled_tweets1, unlabeled_tweets2])

# %%
unlabeled_tweets = unlabeled_tweets[['text']]

# %%
unlabeled_tweets.columns
# Out:
# Index([u'text'], dtype='object')

# %%
len(unlabeled_tweets)
# Out:
# 91028

# %%
def clean_str(string):
    """
    Tokenization/string cleaning for all datasets except for SST.
    Original taken from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " ", string)
    string = re.sub(r"\'ve", " ", string)
    string = re.sub(r"n\'t", " ", string)
    string = re.sub(r"n\'s", " ", string)
    string = re.sub(r"\'re", " ", string)
    string = re.sub(r"\'d", " ", string)
    string = re.sub(r"\'ll", " ", string)
    string = re.sub(r",", " ", string)
    string = re.sub(r"!", " ", string)
    string = re.sub(r"\(", " ", string)
    string = re.sub(r"\)", " ", string)
    string = re.sub(r"\?", " ", string)
    string = re.sub(r"\s{2,}", " ", string)
    string = re.sub(r"\//?", " ", string)
    string = re.sub(r"\d+", " ", string)
    string = re.sub(r"\$", " ", string)
    string = re.sub(r"\#", " ", string)
    return string.strip().lower()

# %%
def remove_stop(str):
    stop = set(stopwords.words('english'))
    lst = str.split()
    lst = [i for i in lst if i not in stop]
    return ' '.join(lst)

def stem (str):
    lst = str.split()
    lst = [st.stem(x) for x in lst]
    return ' '.join(lst)

def remove_unwanted_words(str):
    unwanted_words = ["httpaddress", "usrid", "D", "dd", "rt", "amp", "am", "pm", '``',
                      "''", "", "//", "\\", "\\'s", "\\?", "\?","http","httpaddresshttpaddresst", "cohttpaddressek", "sat", "sun", "mon",
                     "tue", "wed", "thu", "fri", "jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
    lst = str.split(" ")
    lst = [i for i in lst if i not in unwanted_words]
    return ' '.join(lst)


#def remove_unwanted_words(str):
#    unwanted_words = ["httpaddress", "usrid", "D", "dd", "rt", "amp", "am", "pm", '``', 'd',
#                      "''", "", "//", "\\", "\\'s", "\\?", "\?","http","httpaddresshttpaddresst", "cohttpaddressek",
#                      "taksim","gezi", "park", "direngeziparki", "occupygezi", "istanbul", "turkish","turkey",
#                      "protest","direngezipark","direnankara","geziparki", "protesters", "protests", "sat", "sun", "mon,",
#                     "tue", "wed", "thu", "fri", "jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
#    lst = str.split(" ")
#    lst = [i for i in lst if i not in unwanted_words]
#    return ' '.join(lst)

def toLower(str):
    lst = str.split()
    lst = [i.lower() for i in lst]
    return ' '.join(lst)

def word_len (str):
    lst = str.split()
    lst = [i for i in lst if len(i)>1 and len(i) <7]
    return ' '.join(lst)

def sent_len (str):
    lst = str.split()
    if len(lst)>=3:
        return ' '.join(lst)

# %%
def clean_data(data):
    """
    Loads MR polarity african_data from files, splits the african_data into words and generates labels.
    Returns split sentences and labels.
    """
    # Load african_data from files
    positive_examples = data
    positive_examples = positive_examples.strip() 
    positive_examples = remove_stop(positive_examples) 
    #print(positive_examples[0])
    positive_examples = toLower(positive_examples) 
    #rint(positive_examples[0])
    positive_examples = clean_str(positive_examples) 
    #rint(positive_examples[0])
    #positive_examples = [stem(item) for item in positive_examples]
    #rint(positive_examples[0])
    positive_examples = remove_unwanted_words(positive_examples)
    #positive_examples = word_len(positive_examples) 
    positive_examples = sent_len(positive_examples) 
    
    return positive_examples

# %%
unlabeled_tweets['clean_text'] = unlabeled_tweets['text'].apply(lambda x:clean_data(str(x)) )

# %%
unlabeled_tweets['Fatma_violence'] = -1

# %%
unlabeled_tweets
# Out:
#                                                     text  \
# 0      i always without fail get the first cut of the...
# 1      rt usrId massive tear gas clouds fill taksim s...
# 2      rt usrId no arrests were made in yesterday s a...
# 3      rt usrId tango down httpAddress #opturkey #ano...
# 4      rt usrId this huge crowd was today s taksim sq...
# 5      usrId usrId seems to be a secular majority vs ...
# 6      numbers do not lie but deceive behind the faca...
# 7      photoset aidalizeme a series on doors in turke...
# 8      #occupyturkey this is not self protection not ...
# 9      rt usrId #turkey activists reject apology from...
# 10     police attacking and arresting people at kenne...
# 11     young chapullers are so f ing cool ! #direngez...
# 12     insight rapid growth of httpAddress mortgage s...
# 13     how turks face government repression nonviolen...
# 14     rt usrId we fight today for a better tomorrow ...
# 15     rt usrId if water canons are used to disperse ...
# 16                 accountability turkey fascist erdogan
# 17     rt usrId just got some new pics of the #police...
# 18     rt usrId a sign of solidarity from #stuttgart ...
# 19     rt usrId itvnews clean up begins in istanbul a...
# 20     rt usrId cnn world vs cnn turkey right now #oc...
# 21     spontaneous #demonstration on stephansplatz in...
# 22     rt usrId dear #amanpour cnn international must...
# 23     usrId please support the war antakya lot of tu...
# 24     usrId how turkish riot police forces attack la...
# 25     bbc news turkey protests unrest rages in istan...
# 26     rt usrId turkish government has blocked twitte...
# 27     rt usrId #provokatrtayyip turkey pm continues ...
# 28     rt usrId turkish pm erdogan there is now a men...
# 29     rt usrId in turkey at least DD injured as poli...
# ...                                                  ...
# 30339  sharing #suaju wave of unrest spreads across t...
# 30340  moroccans protesting erdogan s visit #direngez...
# 30341  turkey protests 2013 new clashes erupt despite...
# 30342  rt usrId cnn imagine that there is a war happe...
# 30343  #turkey update 1 with tear gaswater cannon rio...
# 30344  #turkey summary #erdogan compromises on #gezip...
# 30345  rt usrId thinking of my friends in turkey who ...
# 30346  rt usrId #erdogan talks of foreigners joining ...
# 30347  me n #turkey don t have lot in common but i m ...
# 30348  rt usrId photo turkish police use tear gas aga...
# 30349  rt usrId i ll be live at D pm istanbul time fr...
# 30350  rt usrId usrId turkish protesters control ista...
# 30351                       turkey club wrap httpAddress
# 30352  the first ever crypto days academic conference...
# 30353  social media is worst menace to society says t...
# 30354  rt usrId statement on the #turkey resolution b...
# 30355    they need to make some maple turkey httpAddress
# 30356  usrId yes turkey she used turkey slices and lo...
# 30357  rt usrId wow talk about a strong strong revolu...
# 30358  #direngeziparki #occupygezi art in the middle ...
# 30359                               menarik nih grafiti
# 30360  insight erdogan wounded not felled by turkish ...
# 30361  how democratic is turkey ? by steven a . cook ...
# 30362  i like this summer of discontent idea in turke...
# 30363                   world news syria turkey updates
# 30364                just want to go to turkey villa now
# 30365  rt usrId turkish spring ? violent clashes rumb...
# 30366  rt usrId shame on us tear gas used in turkey a...
# 30367  rt usrId turkey you are a monument of reason a...
# 30368  rt usrId turkey live httpAddress ankara the po...
#
#                                               clean_text  Fatma_violence
# 0      always without fail get first cut fresh turkey...              -1
# 1      massive tear gas clouds fill taksim square ist...              -1
# 2      arrests made yesterday akp terror attack peopl...              -1
# 3                 tango opturkey anonymous redhack folks              -1
# 4      huge crowd today taksim square myriamonde earl...              -1
# 5      seems secular majority vs non secular religiou...              -1
# 6      numbers lie deceive behind facade turkeys rece...              -1
# 7                photoset aidalizeme series doors turkey              -1
# 8      occupyturkey self protection rage please help ...              -1
# 9      turkey activists reject apology deputy demand ...              -1
# 10     police attacking arresting people kennedy str ...              -1
# 11     young chapullers f ing cool direngeziparki dir...              -1
# 12     insight rapid growth mortgage servicers draws ...              -1
# 13     turks face government repression nonviolent re...              -1
# 14     fight today better tomorrow egypt turkey brazi...              -1
# 15            water canons used disperse crowd poisonous              -1
# 16                 accountability turkey fascist erdogan              -1
# 17     got new pics policeviolence turkey disgusting ...              -1
# 18              sign solidarity stuttgart occupygezi via              -1
# 19     itvnews clean begins istanbul protester number...              -1
# 20           cnn world vs cnn turkey right occupygezi un              -1
# 21     spontaneous demonstration stephansplatz vienna...              -1
# 22     dear amanpour cnn international must pull name...              -1
# 23                 please support war antakya lot turkey              -1
# 24     turkish riot police forces attack lawyers occu...              -1
# 25     bbc news turkey protests unrest rages istanbul...              -1
# 26     turkish government blocked twitter please game...              -1
# 27     provokatrtayyip turkey continues hate speechs ...              -1
# 28     turkish erdogan menace called twitter social m...              -1
# 29     turkey least injured police clash protesters g...              -1
# ...                                                  ...             ...
# 30339  sharing suaju wave unrest spreads across turke...              -1
# 30340  moroccans protesting erdogan visit direngezipa...              -1
# 30341  turkey protests new clashes erupt despite depu...              -1
# 30342  cnn imagine war happening times square news br...              -1
# 30343  turkey update tear gaswater cannon riot police...              -1
# 30344  turkey summary erdogan compromises gezipark fa...              -1
# 30345          thinking friends turkey fight power today              -1
# 30346  erdogan talks foreigners joining gezipark prot...              -1
# 30347  n turkey lot common revolution n iliketurkeych...              -1
# 30348  photo turkish police use tear gas environmenta...              -1
# 30349      live d istanbul time taksim cnn international              -1
# 30350  turkish protesters control istanbul square two...              -1
# 30351                                   turkey club wrap              -1
# 30352  first ever crypto days academic conference tur...              -1
# 30353  social media worst menace society says turkey ...              -1
# 30354  statement turkey resolution solidar dvv intern...              -1
# 30355                             need make maple turkey              -1
# 30356          yes turkey used turkey slices lots cheese              -1
# 30357  wow talk strong strong revolutionary image tur...              -1
# 30358  direngeziparki occupygezi art middle protests ...              -1
# 30359                                menarik nih grafiti              -1
# 30360  insight erdogan wounded felled turkish protest...              -1
# 30361  democratic turkey steven cook michael koplow f...              -1
# 30362  like summer discontent idea turkey ataturk sec...              -1
# 30363                    world news syria turkey updates              -1
# 30364                               want go turkey villa              -1
# 30365  turkish spring violent clashes rumble night is...              -1
# 30366  shame us tear gas used turkey demonstrators ma...              -1
# 30367            turkey monument reason slide islamic ne              -1
# 30368  turkey live ankara police told crowd disperse ...              -1
#
# [91028 rows x 3 columns]

# %%
unlabeled_tweets.to_csv('Data/unlabeled_turkish_tweets_processd.csv')
